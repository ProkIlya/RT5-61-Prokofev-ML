# %% [markdown]
# # Лабораторная работа: Предварительная обработка данных
# # Цель: изучение способов предварительной обработки данных для дальнейшего формирования моделей.
# #
# # Используется датасет Engineering_books_data.csv

# %%
# Импорт необходимых библиотек
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, StandardScaler, MinMaxScaler

# Настройка отображения
pd.set_option('display.max_columns', None)
pd.set_option('display.width', 1000)


# Загрузка данных
df = pd.read_csv('Engineering_books_data.csv', encoding='utf-8')

# Первичный просмотр данных
print("Первые 5 строк датасета:")
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 12
#       8 pd.set_option('display.width', 1000)
#      11 # Загрузка данных
# ---> 12 df = pd.read_csv('D:\6 семестр\ML\lab2\Engineering_books_data.csv', encoding='utf-8')
#      14 # Первичный просмотр данных
#      15 print("Первые 5 строк датасета:")
#
# ...
